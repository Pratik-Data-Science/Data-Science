# %% [markdown]
# ### Descriptive Statistics 2 - Theory

# %% [markdown]
# ---

# %% [markdown]
# #### What is Quantile and Percentiles?

# %% [markdown]
# <b> 1. Quantiles:</b>Quantiles are statistical measures used to divide a set of numerical data into
# equal-sized groups, with each group containing an equal number of observations.
# Quantiles are important measures of variability and can be used to: understand
# distribution of data, summarize and compare different datasets. They can also be
# used to identify outliers.
#
# There are several types of quantiles used in statistical analysis, including:
#
# <b>a. Quartiles:</b> Divide the data into four equal parts, Q1 (25th percentile), Q2
# (50th percentile or median), and Q3 (75th percentile).<br>
# <b>b. Deciles:</b> Divide the data into ten equal parts, D1 (10th percentile), D2
# (20th percentile), ..., D9 (90th percentile).<br>
# <b>c. Percentiles:</b> Divide the data into 100 equal parts, P1 (1st percentile), P2
# (2nd percentile), ..., P99 (99th percentile).<br>
# <b>d. Quintiles:</b> Divides the data into 5 equal parts
#
# 1. Data should be sorted from low to high
# 2. You are basically finding the location of an observation
# 3. They are not actual values in the data
# 4. All other tiles can be easily derived from Percentiles
#
# <b>2. Percentile</b>
# A percentile is a statistical measure that represents the percentage of observations in a
# dataset that fall below a particular value. For example, the 75th percentile is the value below
# which 75% of the observations in the dataset fall.
# Formula to calculate the percentile value:
#
# PL = p/100(N+1)<br>
# where:<br>
# • PL = the desired percentile value location
# • N = the total number of observations in the dataset
# • p = the percentile rank (expressed as a percentage)

# %% [markdown]
# ---

# %% [markdown]
# #### What is 5 number summary?

# %% [markdown]
# The five-number summary is a descriptive statistic that provides a summary of a
# dataset. It consists of five values that divide the dataset into four equal parts, also
# known as quartiles. The five-number summary includes the following values:
#
# <b>1. Minimum value:</b> The smallest value in the dataset.<br>
# <b>2. First quartile (Q1):</b> The value that separates the lowest 25% of the data from
# the rest of the dataset.<br>
# <b>3. Median (Q2):</b> The value that separates the lowest 50% from the highest 50%
# of the data.<br>
# <b>4. Third quartile (Q3):</b> The value that separates the lowest 75% of the data from
# the highest 25% of the data.<br>
# <b>5. Maximum value:</b> The largest value in the dataset.
#
# The five-number summary is often represented visually using a box plot, which
# displays the range of the dataset, the median, and the quartiles.
# The five-number summary is a useful way to quickly summarize the central
# tendency, variability, and distribution of a dataset.

# %% [markdown]
# ---

# %% [markdown]
# #### What is Interquartile range?

# %% [markdown]
# The interquartile range (IQR) is a measure of variability that is based on the five-number
# summary of a dataset. Specifically, the IQR is defined as the difference between the third
# quartile (Q3) and the first quartile (Q1) of a dataset.

# %% [markdown]
# ---

# %% [markdown]
# #### What is Boxplot?

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a graphical representation of a
# dataset that shows the distribution of the data. The box plot displays a summary of the
# data, including the minimum and maximum values, the first quartile (Q1), the median
# (Q2), and the third quartile (Q3).
#
# Minimum value = Q1 - 1.5*IQR<br>
# Maximun value = Q1 + 1.5*IQR<br>

# %% [markdown]
# ---

# %% [markdown]
# #### What are the benefits of Boxplot?

# %% [markdown]
# Boxplots offer several benefits in data visualization and analysis:
#
# <b>1. Summary of Data Distribution:</b> They provide a visual summary of the distribution of a dataset, including the median, quartiles, and potential outliers.<br>
# <b>2. Identification of Outliers:</b> They help in identifying outliers in the data, which are data points that significantly differ from the rest of the dataset.<br>
# <b>3. Comparison of Distributions:</b> Boxplots allow for easy comparison of the distributions of multiple datasets or groups, making them useful for exploratory data analysis.<br>
# <b>4. Space-Efficient:</b> They are space-efficient, providing a lot of information in a compact visual display.<br>
# <b>5. Robustness:</b> They are robust against extreme values and asymmetry in the data, making them useful for skewed datasets.<br>
# <b>6. Clarity:</b> They provide a clear visual representation of the central tendency and spread of the data.

# %% [markdown]
# ---

# %% [markdown]
# #### What problem does covariance solve?

# %% [markdown]
# The main problem that covariance helps to solve is to quantify the degree to which two variables tend to deviate from their means in similar ways. This is important in understanding the linear relationship between variables in statistics and machine learning.

# %% [markdown]
# ---

# %% [markdown]
# #### What is covariance and how it is interpreted?

# %% [markdown]
# Covariance is a statistical measure that describes the degree to which two variables are
# linearly related. It measures how much two variables change together, such that when
# one variable increases, does the other variable also increase, or does it decrease?
#
# If the covariance between two variables is positive, it means that the variables tend to
# move together in the same direction. If the covariance is negative, it means that the
# variables tend to move in opposite directions. A covariance of zero indicates that the
# variables are not linearly related.

# %% [markdown]
# ---

# %% [markdown]
# #### What is the disadvantage of covariance?

# %% [markdown]
# One limitation of covariance is that it does not tell us about the strength of the
# relationship between two variables, since the magnitude of covariance is affected by the
# scale of the variables.
#
# The main demerit of covariance is that it is not a standardized measure, meaning it is influenced by the scales of the variables involved. This makes it challenging to interpret the magnitude of the covariance and compare the relationships between variables with different scales.
#
# Additionally, covariance doesn't provide a clear indication of the strength and direction of the relationship between variables. This makes it difficult to determine the degree to which changes in one variable are associated with changes in another.
#
# Due to these limitations, covariance is often replaced by correlation, which is a standardized measure that provides a clearer indication of the strength and direction of the relationship between variables.

# %% [markdown]
# ---

# %% [markdown]
# #### What happens when we calculate covariance of a vraible with itself?

# %% [markdown]
# When we calculate covariance of a column with itself then it actually calculates variance

# %% [markdown]
# ---

# %% [markdown]
# #### What is correlation?

# %% [markdown]
# Correlation refers to a statistical relationship between two or more variables.
# Specifically, it measures the degree to which two variables are related and
# how they tend to change together.
#
# Correlation is often measured using a statistical tool called the correlation
# coefficient, which ranges from -1 to 1. A correlation coefficient of -1 indicates
# a perfect negative correlation, a correlation coefficient of 0 indicates no
# correlation, and a correlation coefficient of 1 indicates a perfect positive
# correlation.

# %% [markdown]
# ---

# %% [markdown]
# #### Correlation vs Causation?

# %% [markdown]
# The phrase "correlation does not imply causation" means that just because
# two variables are associated with each other, it does not necessarily mean that
# one causes the other. In other words, a correlation between two variables
# does not necessarily imply that one variable is the reason for the other
# variable's behaviour.
#
# Suppose there is a positive correlation between the number of firefighters
# present at a fire and the amount of damage caused by the fire. One might be
# tempted to conclude that the presence of firefighters causes more damage.
# However, this correlation could be explained by a third variable - the severity
# of the fire. More severe fires might require more firefighters to be present, and
# also cause more damage.
#
# Thus, while correlations can provide valuable insights into how different
# variables are related, they cannot be used to establish causality. Establishing
# causality often requires additional evidence such as experiments, randomized
# controlled trials, or well-designed observational studies.

# %% [markdown]
# ---

# %% [markdown]
# #### What is Random variables?

# %% [markdown]
# A Random Variable is a set of possible values from a random experiment. Random variables are a fundamental concept in statistics and probability theory. They represent numerical outcomes of a random phenomenon, and they can take on different values based on the result of a random process or experiment.
#
# There are two main types of random variables:
#
# <b>1. Discrete random variables:</b> These variables can take on a finite number of distinct values or an infinite sequence of values that can be counted. For example, the number of heads obtained when flipping three coins is a discrete random variable because it can take on the values 0, 1, 2, or 3.<br>
# <b>2. Continuous random variables:</b> These variables can take on any value within a certain range. They are often associated with measurements and can take on an uncountably infinite number of possible values. For example, the weight of a person or the time taken to complete a task are continuous random variables.<br>
# Random variables are essential for understanding the probability of different outcomes in various scenarios and are widely used in fields such as economics, engineering, and the natural sciences.

# %% [markdown]
# ---

# %% [markdown]
# #### What is probability distribution?

# %% [markdown]
# A probability distribution is a list of all of the possible outcomes of a random variable
# along with their corresponding probability values.
#
# A probability distribution describes the likelihood of possible outcomes in a statistical experiment. It tells us how probable different outcomes are. For example, a normal distribution shows how data is spread around the mean, while a binomial distribution describes the number of successes in a fixed number of trials.

# %% [markdown]
# ---

# %% [markdown]
# #### What is the problem with probablity distribution?

# %% [markdown]
# In many scenarios, the number of outcomes can be much larger and hence a table would
# be tedious to write down. Worse still, the number of possible outcomes could be infinite,
# in which case, good luck writing a table for that.
#
# Example - Height of people, Rolling 10 dice together

# %% [markdown]
# ---

# %% [markdown]
# #### What is the solution to overcome this limitation?

# %% [markdown]
# We can use a mathematical function to model the relationship between outcome and
# probability. We can form a probability distribution function

# %% [markdown]
# *** Note - A lot of time Probability Distribution and Probability Distribution Functions are
# used interchangeably.

# %% [markdown]
# ---

# %% [markdown]
# #### What is probablity distribution function?

# %% [markdown]
# A probability distribution function, often denoted as PDF, describes the likelihood of a random variable to take on a certain value. For continuous random variables, the PDF represents the probability of the variable falling within a particular range of values. It's a fundamental concept in statistics and probability theory. Understanding the PDF is crucial for various analytical and modeling tasks.
#
# <b>1. Discrete random variable probability distribution function (PDF):</b> It describes the likelihood of each possible value that the variable can take. It's typically represented by a probability mass function (PMF) and is used for variables with a finite or countably infinite set of possible values, like the outcome of rolling a die.
#
# <b>2. Continuous random variable probability distribution function (PDF):</b> It represents the probability distribution for continuous variables, typically over an interval of values. Instead of probability mass functions, continuous random variables are described using probability density functions (PDFs), indicating the likelihood of the variable falling within a specific range of values.

# %% [markdown]
# ---

# %% [markdown]
# #### Why are Probability Distributions important?

# %% [markdown]
# - Gives an idea about the shape/distribution of the data.
# - And if our data follows a famous distribution then we automatically know a lot about the
# data.

# %% [markdown]
# ---

# %% [markdown]
# #### A note on Parameters

# %% [markdown]
# Parameters in probability distributions are numerical values that determine the shape,
# location, and scale of the distribution.
#
# Different probability distributions have different sets of parameters that determine their
# shape and characteristics, and understanding these parameters is essential in statistical
# analysis and inference

# %% [markdown]
# ---

# %% [markdown]
# #### What are the two types of probability distribution function?

# %% [markdown]
# A probability distribution function (PDF) is a mathematical function that describes
# the probability of obtaining different values of a random variable in a particular
# probability distribution. The two types of PDFs are:
#
# <b>1. PMF: </b>PMF stands for Probability Mass Function. It is a mathematical function that
# describes the probability distribution of a discrete random variable.
# The PMF of a discrete random variable assigns a probability to each possible value
# of the random variable. The probabilities assigned by the PMF must satisfy two
# conditions:
#
# - The probability assigned to each value must be non-negative (i.e., greater
# than or equal to zero).
# - b. The sum of the probabilities assigned to all possible values must equal 1
#
# <b>2. PDF: </b>PDF stands for Probability Density Function. It is a mathematical function that
# describes the probability distribution of a continuous random variable.
#
# <b>3. CDF: </b>CDF stands for Cummalative Distribution Function. The cumulative distribution function (CDF) F(x) describes the probability that a
# random variable X with a given probability distribution will be found at a value less
# than or equal to x

# %% [markdown]
# ---

# %% [markdown]
# #### What is Probability Density Function?

# %% [markdown]
# It is a mathematical function that
# describes the probability distribution of a continuous random variable.

# %% [markdown]
# ---

# %% [markdown]
# #### What is the difference between PMF and PDF?

# %% [markdown]
# - PMF describes the probability distribution of a discrete random variable whereas PDF describes the probability distribution of a continuous random variable
# - In PMF, y-axis denotes the probability whereas in PDF, the y-axis denotes probability density

# %% [markdown]
# ---

# %% [markdown]
# #### In PDF, why there is probability density instead of probability?

# %% [markdown]
# Since PDF is calculated for continuous values, so it is very difficult to find the probability of a particular value. Its probability will be close to zero. And if we plot such probability, it will not make sense

# %% [markdown]
# ---

# %% [markdown]
# #### In PDF, what does the under the graph represents?

# %% [markdown]
# This actually represnts the probability between two data points

# %% [markdown]
# ---

# %% [markdown]
# #### What is Density Estimation?

# %% [markdown]
# Density estimation is a statistical technique used to estimate the probability
# density function (PDF) of a random variable based on a set of observations or data.
# In simpler terms, it involves estimating the underlying distribution of a set of data
# points.
#
# Density estimation can be used for a variety of purposes, such as hypothesis
# testing, data analysis, and data visualization. It is particularly useful in areas such
# as machine learning, where it is often used to estimate the probability distribution
# of input data or to model the likelihood of certain events or outcomes.
#
# There are various methods for density estimation, including parametric and nonparametric approaches. Parametric methods assume that the data follows a
# specific probability distribution (such as a normal distribution), while nonparametric methods do not make any assumptions about the distribution and
# instead estimate it directly from the data.
#
# Commonly used techniques for density estimation include kernel density
# estimation (KDE), histogram estimation, and Gaussian mixture models (GMMs).
# The choice of method depends on the specific characteristics of the data and the
# intended use of the density estimate.

# %% [markdown]
# ---

# %% [markdown]
# #### What are different types of Density Estimation?

# %% [markdown]
# There are two types of Density Estimation. They are:
#
# <b>1. Parametric Density Estimation: </b> Parametric density estimation is a method of estimating the probability density
# function (PDF) of a random variable by assuming that the underlying distribution
# belongs to a specific parametric family of probability distributions, such as the
# normal, exponential, or Poisson distributions.
#
# <b>2. Non - Parametric Density Estimation: </b>But sometimes the distribution is not clear or it's not one of the famous distributions.
# Non-parametric density estimation is a statistical technique used to estimate the probability
# density function of a random variable without making any assumptions about the underlying
# distribution. It is also referred to as non-parametric density estimation because it does not
# require the use of a predefined probability distribution function, as opposed to parametric
# methods such as the Gaussian distribution.
# The non-parametric density estimation technique involves constructing an estimate of the
# probability density function using the available data. This is typically done by creating a kernel
# density estimate
#
# Non-parametric density estimation has several advantages over parametric density
# estimation. One of the main advantages is that it does not require the assumption of a
# specific distribution, which allows for more flexible and accurate estimation in situations
# where the underlying distribution is unknown or complex. However, non-parametric density
# estimation can be computationally intensive and may require more data to achieve accurate
# estimates compared to parametric methods.

# %% [markdown]
# ---

# %% [markdown]
# #### What is KDE?

# %% [markdown]
# KDE (Kernal Density Function) is a technique to plot non-parametric denssity function using a kernel function to smooth out the data and create a
# continuous estimate of the underlying density function.
#
# For every data point, a gausion distribution is created and then for every point all the y-value are added. All these points add upto create a plot.
#
# It takes two inputs - Kernal(gausian) which is mean and bandwidth which is standard deviation

# %% [markdown]
# *** if we have PDF, we can create CDF with the help of are under the curve(performing integration). If we have CDF, we can create PDF by calculating slope at each point(performing differentiation)

# %% [markdown]
# *** PDF has to be used before applying any Machine Learning algorithms
